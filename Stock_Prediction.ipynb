# %% [markdown]
# <a href="https://colab.research.google.com/github/roshank1605A04/Stock-Market-Predictions/blob/master/Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Prediction
# ## Rahul Bharadwaaj

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-72a06236-f755-497f-bc9d-bb1bde5f7721" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72a06236-f755-497f-bc9d-bb1bde5f7721">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Train.csv to Google_Stock_Price_Train (2).csv

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d18b556e-e7d3-4a64-b703-6055c376e1ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d18b556e-e7d3-4a64-b703-6055c376e1ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Test.csv to Google_Stock_Price_Test (3).csv

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
training_data = pd.read_csv('Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# feature scaling

from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
# reshaping

x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 2ms/step - loss: 0.2447
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1803
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1368
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1095
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0936
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0849
# Epoch 7/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0802
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0775
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0759
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0747
# Epoch 11/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0735
# Epoch 12/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0724
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0713
# Epoch 14/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 16/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0676
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0663
# Epoch 18/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0650
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0622
# Epoch 21/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0608
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0593
# Epoch 23/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0577
# Epoch 24/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0561
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 26/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0528
# Epoch 27/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0511
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0493
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0475
# Epoch 30/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0456
# Epoch 31/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0437
# Epoch 32/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0418
# Epoch 33/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0398
# Epoch 34/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0378
# Epoch 35/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0357
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0337
# Epoch 37/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0296
# Epoch 39/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 42/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0216
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0197
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 52/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 53/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 59/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 61/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 62/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 63/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 64/200
# 40/40 [==============================] - 0s 2ms/step - loss: 9.4621e-04
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 8.2434e-04
# Epoch 66/200
# 40/40 [==============================] - 0s 2ms/step - loss: 7.2562e-04
# Epoch 67/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.5087e-04
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.9169e-04
# Epoch 69/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.4683e-04
# Epoch 70/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.1286e-04
# Epoch 71/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.8313e-04
# Epoch 72/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.6451e-04
# Epoch 73/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.4646e-04
# Epoch 74/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.3467e-04
# Epoch 75/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.2535e-04
# Epoch 76/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.1705e-04
# Epoch 77/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.1167e-04
# Epoch 78/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.0712e-04
# Epoch 79/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.0336e-04
# Epoch 80/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.0054e-04
# Epoch 81/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9748e-04
# Epoch 82/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.9460e-04
# Epoch 83/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9239e-04
# Epoch 84/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.9079e-04
# Epoch 85/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8983e-04
# Epoch 86/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8603e-04
# Epoch 87/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8404e-04
# Epoch 88/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8202e-04
# Epoch 89/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.8036e-04
# Epoch 90/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.7824e-04
# Epoch 91/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.7590e-04
# Epoch 92/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.7409e-04
# Epoch 93/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.7195e-04
# Epoch 94/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7022e-04
# Epoch 95/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6785e-04
# Epoch 96/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6661e-04
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6524e-04
# Epoch 98/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6353e-04
# Epoch 99/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6021e-04
# Epoch 100/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5855e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5712e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5476e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5169e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5052e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4830e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4658e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4507e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4443e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4112e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3863e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3633e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3477e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3312e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3114e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3108e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.2825e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.2824e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.2658e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.2295e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.2028e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.1918e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1813e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.1673e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.1413e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.1209e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.1098e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 3ms/step - loss: 3.0956e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 4ms/step - loss: 3.0882e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0748e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0447e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0577e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0211e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0122e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9880e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0045e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9765e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9980e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9400e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9265e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9367e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.9059e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8997e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8999e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8692e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8859e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8672e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8502e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8274e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8321e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8208e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8083e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8230e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8089e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7923e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.8029e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7923e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7785e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7662e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7448e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7561e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7456e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7357e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7818e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.7082e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7173e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7052e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7320e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6846e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6798e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6675e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7101e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6920e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6718e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6788e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6906e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6501e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6389e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6616e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6583e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6456e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6542e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6355e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6354e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6226e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6256e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6475e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6467e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6190e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6465e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6914e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6156e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6469e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6637e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6410e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6679e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6205e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6174e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6163e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6213e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6043e-04

# %%
# getting the real stock of 2017 i.e., importing the test dataset

test_data = pd.read_csv('Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165],
#        [1.7093165]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# getting the predicted stock price of 2012-2016

predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
# visualizing the whole training data results

plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
